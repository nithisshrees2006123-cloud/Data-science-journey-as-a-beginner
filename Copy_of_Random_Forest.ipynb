# %% [markdown]
# <a href="https://colab.research.google.com/github/nithisshrees2006123-cloud/Data-science-journey-as-a-beginner/blob/main/Copy_of_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/customer_churn (3).csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# eda

df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 42.40      1
# 97.90      1
# 116.40     1
# 31.65      1
# 39.05      1
# Name: count, Length: 1585, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df['TotalCharges'].value_counts()
# Out:
# TotalCharges
#            11
# 20.2       11
# 19.75       9
# 20.05       8
# 19.9        8
#            ..
# 130.15      1
# 3211.9      1
# 7843.55     1
# 2196.3      1
# 197.4       1
# Name: count, Length: 6531, dtype: int64

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors ='coerce')

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop(columns =['customerID'], inplace = True)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
col_list = []

for i in df.columns:
  if((df[i].dtypes =='object')&(i != 'Churn')):
    col_list.append(i)

# %%
col_list
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
for i in col_list:

  df[i] = le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   int64
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   int64
#  3   Dependents        7032 non-null   int64
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   int64
#  6   MultipleLines     7032 non-null   int64
#  7   InternetService   7032 non-null   int64
#  8   OnlineSecurity    7032 non-null   int64
#  9   OnlineBackup      7032 non-null   int64
#  10  DeviceProtection  7032 non-null   int64
#  11  TechSupport       7032 non-null   int64
#  12  StreamingTV       7032 non-null   int64
#  13  StreamingMovies   7032 non-null   int64
#  14  Contract          7032 non-null   int64
#  15  PaperlessBilling  7032 non-null   int64
# ...

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
x = df.iloc[ :, :-1]
#iloc - fetch the data using indexing#
#[ :] ->all the rows


x
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y = df['Churn']

# %%
y
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7032, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.20, random_state = 42, stratify= y)

# %%
x_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1413       1              0        1           1      65             1
# 7003       1              0        0           0      26             0
# 3355       0              0        1           0      68             1
# 4494       1              0        0           0       3             1
# 3541       0              0        1           0      49             0
# ...      ...            ...      ...         ...     ...           ...
# 3451       1              1        1           0      65             1
# 5123       0              1        0           0      15             1
# 4135       0              0        1           1      36             1
# 4249       0              0        1           1      10             1
# 1505       1              1        0           0       1             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
x_test
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 974        0              0        1           1      59             1
# 619        0              0        0           0       7             1
# 4289       0              0        0           0      54             1
# 3721       0              0        0           0       2             1
# 4533       0              0        1           0      71             1
# ...      ...            ...      ...         ...     ...           ...
# 4829       0              0        0           0      12             1
# 5176       0              0        0           1      26             0
# 2750       1              0        0           0       3             1
# 4432       1              0        0           0      37             0
# 2091       0              0        0           1      50             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
y_train
# Out:
# 1413     No
# 7003     No
# 3355     No
# 4494     No
# 3541     No
#        ...
# 3451     No
# 5123    Yes
# 4135     No
# 4249     No
# 1505    Yes
# Name: Churn, Length: 5625, dtype: object

# %%
y_test
# Out:
# 974      No
# 619      No
# 4289     No
# 3721    Yes
# 4533     No
#        ...
# 4829     No
# 5176     No
# 2750     No
# 4432     No
# 2091     No
# Name: Churn, Length: 1407, dtype: object

# %%
# model buidling

from sklearn.ensemble  import RandomForestClassifier

# %%
rfmodel1 = RandomForestClassifier(n_estimators=100)

# %%
rfmodel1.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
ans = rfmodel1.predict(x_test)

# %%
ans
# Out:
# array(['No', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import *

# %%
accuracy_score(y_test, ans)
# Out:
# 0.7860696517412935

# %%
cm  = confusion_matrix(y_test, ans)
cm

# 923 + 188 =  1,111
# 110 + 186 =  296
# Out:
# array([[923, 110],
#        [191, 183]])

# %%
# hyperparameter tuning



from sklearn.model_selection import GridSearchCV

# %%
param = {'n_estimators':[200],
         'max_depth':[10],
         'min_samples_leaf':[2],
         'max_samples':[0.8,0.9,1.0],
         'criterion':['gini','entropy']}

# %%
classifer2 = RandomForestClassifier(random_state = 0)

# %%
grid_search = GridSearchCV(estimator= classifer2 , param_grid=param, n_jobs=-1, cv = 7, verbose=1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 7 folds for each of 6 candidates, totalling 42 fits
# GridSearchCV(cv=7, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [10],
#                          'max_samples': [0.8, 0.9, 1.0],
#                          'min_samples_leaf': [2], 'n_estimators': [200]},
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'max_samples': 0.8,
#  'min_samples_leaf': 2,
#  'n_estimators': 200}

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classfier3 =  RandomForestClassifier(n_estimators=200,criterion ='entropy',max_depth=10,max_samples=0.8,min_samples_leaf=2 )

# %%
classfier3.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, max_samples=0.8,
#                        min_samples_leaf=2, n_estimators=200)

# %%
y_pred = classfier3.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7882018479033405

# %%
param = {'n_estimators':[200],
         'max_depth':[10],
         'min_samples_leaf':[2],
         'max_samples':[0.8,0.9,1.0],
         'criterion':['gini','entropy']}
grid_search = GridSearchCV(estimator=classifer2, param_grid=param, cv=7, n_jobs=-1, verbose=2)
grid_search.fit(x_train, y_train)
y_pred = grid_search.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# Fitting 7 folds for each of 6 candidates, totalling 42 fits
# 0.7910447761194029
